# %% [markdown]
# El primer paso consiste en seleccionar un entorno de ejecución con una GPU, google nos da 5 horas de una GPU T4, con este uso tenemos tiempo de sobra para realizar pruebas y entrenar nuestro modelo.
#
# Para seleccionar este estorno seleccionamos **Conectar** en la esquina superior derecha, seleccionando el icono de los recursos en la misma ubicación poder ver un desglose del tiempo , junto a la RAM, memoria VRAM y espacio de disco disponible.

# %%
# Importamos y nos conectamos a nuestro drive que es donde debemos colocar nuestro proyecto
from google.colab import drive
drive.mount('/content/drive')

# %%
# Seleccionamos la carpeta exacta donde tenemos nuestro proyecto y lo sustituimos en la ruta:
# %cd /content/drive/MyDrive/Entrenamiento 19-03-26

# %%
# instalamos los requisitos
#!pip install -r requirements.txt
# !pip install -e .

# %%
# importamos las librerias y comprobamos que se ha instalado los requisitos correctamente
import numpy as np
import torch
import tensorboard
import sentencepiece
import requests
import tqdm

print(f"NumPy version: {np.__version__}")
print(f"Requests version: {requests.__version__}")
print(f"SentencePiece version: {sentencepiece.__version__}")
print(f"TensorBoard version: {tensorboard.__version__}")
print(f"Torch version: {torch.__version__}")
print(f"TQDM version: {tqdm.__version__}")

import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %%
# !python -m smolgpt.train
